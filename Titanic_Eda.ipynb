# %% [markdown]
# ## Titanic Dataset: EDA and Data Cleaning with Pandas

# %% [markdown]
# ### Loading and Inspecting Data

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Titanic dataset into a pandas DataFrame.

df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Display the first 5 rows.

df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Show the last 10 rows.

df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# Get the shape of the DataFrame.

df.shape
# Out:
# (891, 12)

# %%
# Display the column names.

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Show the data types of each column.

df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Check for missing values in each column.

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Get summary statistics for all numeric columns.

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Get summary statistics for all columns, including non-numeric ones.

df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
# View the index and column info separately

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## Selecting and Filtering

# %%
# Select the "Name" column.
df[['Name']]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
# Select "Name", "Sex", and "Age" columns.

df[['Name','Sex','Age']]
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %%
# Filter passengers older than 60.

df[df['Age']>60]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
# Filter passengers who paid fare greater than $100.
df[df['Fare'] > 100]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %%
# Filter female passengers.

df[df['Sex']=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Select passengers who are female and older than 50.
df[(df['Sex']=='female' ) & (df['Age']>50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 195          196         1       1
# 268          269         1       1
# 275          276         1       1
# 366          367         1       1
# 483          484         1       3
# 496          497         1       1
# 513          514         1       1
# 571          572         1       1
# 591          592         1       1
# 765          766         1       1
# 772          773         0       2
# 774          775         1       2
# 820          821         1       1
# 829          830         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 195                               Lurette, Miss. Elise  female  58.0      0
# ...

# %%
# Select passengers with Cabin info not missing.
df[df['Cabin'].notna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Select passengers who embarked from ‘S’.
df[df['Embarked']=='S']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
# Use .iloc to get the first row.
df.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
# Use .loc to get the row with index 5.

df.loc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %% [markdown]
# ### Sorting and Ranking

# %%
# Sort the dataset by 'Age' in ascending order.
df.sort_values(by='Age')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# Sort by 'Fare' in descending order.
df.sort_values(by='Fare',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
# Sort by 'Pclass' and then by 'Age'.
df.sort_values(['Pclass','Age'])
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 305          306         1       1            Allison, Master. Hudson Trevor
# 297          298         0       1              Allison, Miss. Helen Loraine
# 445          446         1       1                 Dodge, Master. Washington
# 802          803         1       1       Carter, Master. William Thornton II
# 435          436         1       1                 Carter, Miss. Lucile Polk
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# Rank passengers by 'Fare'.

df['FareRank']=df['Fare'].rank(ascending=False)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Show top 5 passengers who paid the highest fare.

df.nlargest(5, 'Fare')
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 27            28         0       1      Fortune, Mr. Charles Alexander
# 88            89         1       1          Fortune, Miss. Mabel Helen
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
#
#      FareRank
# 258       2.0
# 679       2.0
# 737       2.0
# 27        5.5
# 88        5.5

# %% [markdown]
# ### Aggregations and Descriptive Stats

# %%
# Count how many passengers are in each class (Pclass).

df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# Calculate the mean age of passengers.
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
# Find the median fare.
df['Fare'].median()
# Out:
# 14.4542

# %%
# Find the max and min fare.

print(" Max_fare: ", df['Fare'].max())
print(" Min_fare: ", df['Fare'].min())
# Out:
#  Max_fare:  512.3292
#  Min_fare:  0.0

# %%
# Count number of unique ticket numbers.

df['Ticket'].nunique()
# Out:
# 681

# %%
# Use .value_counts() on 'Embarked'.
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# Calculate survival rate by gender.
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
# Calculate average age by 'Pclass'.
df.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %% [markdown]
# ### Data Cleaning

# %%
# Replace missing 'Age' values with median.

df['Age'].fillna(df['Age'].median(),inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2880\1130003502.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(),inplace=True)

# %%
# Fill missing 'Embarked' with the most common value.

df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2880\2345947644.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)

# %%
# Drop the 'Cabin' column.

df.drop(columns='Cabin',inplace=True)

# %%
# Drop rows where 'Embarked' is missing.

df.dropna(subset=['Embarked'],inplace=True)

# %%
# Convert 'Sex' column to lowercase.

df['Sex']=df['Sex'].str.lower()
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 461          462         0       3               Morley, Mr. William    male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"    male
# 690          691         1       1           Dick, Mr. Albert Adrian    male
# 847          848         0       3                Markoff, Mr. Marin    male
# 852          853         0       3           Boulos, Miss. Nourelain  female
#
#       Age  SibSp  Parch  Ticket     Fare Embarked  FareRank
# 461  34.0      0      0  364506   8.0500        S     628.0
# 481  28.0      0      0  239854   0.0000        S     884.0
# 690  31.0      1      0   17474  57.0000        S     126.5
# 847  35.0      0      0  349213   7.8958        C     687.5
# 852   9.0      1      1    2678  15.2458        C     428.0

# %%
# Strip white spaces in column names.

df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked', 'FareRank'],
#       dtype='object')

# %%
# Rename the 'Fare' column to 'TicketPrice'.

df.rename(columns={'Fare':'TicketPrice'},inplace=True)
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 60            61         0       3               Sirayanian, Mr. Orsen
# 457          458         1       1   Kenyon, Mrs. Frederick R (Marion)
# 59            60         0       3  Goodwin, Master. William Frederick
#
#         Sex   Age  SibSp  Parch   Ticket  TicketPrice Embarked  FareRank
# 60     male  22.0      0      0     2669       7.2292        C     829.0
# 457  female  28.0      1      0    17464      51.8625        S     157.5
# 59     male  11.0      5      2  CA 2144      46.9000        S     168.5

# %% [markdown]
# ###  Transformations

# %%
# Create a new column 'FamilySize' = SibSp + Parch + 1.

df['FamilySize']=df['SibSp']+df['Parch']+1
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass  \
# 749          750         0       3
# 187          188         1       1
# 369          370         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 749                        Connaghton, Mr. Michael    male  31.0      0
# 187  Romaine, Mr. Charles Hallace ("Mr C Rolmane")    male  45.0      0
# 369                  Aubart, Mme. Leontine Pauline  female  24.0      0
#
#      Parch    Ticket  TicketPrice Embarked  FareRank  FamilySize
# 749      0    335097         7.75        Q     768.5           1
# 187      0    111428        26.55        S     277.0           1
# 369      0  PC 17477        69.30        C     113.5           1

# %%
# Create a new column 'IsMinor' for Age < 18.

df['IsMinor']=df['Age'] < 18
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 582          583         0       2                Downton, Mr. William James
# 254          255         0       3  Rosblom, Mrs. Viktor (Helena Wilhelmina)
# 480          481         0       3            Goodwin, Master. Harold Victor
#
#         Sex   Age  SibSp  Parch   Ticket  TicketPrice Embarked  FareRank  \
# 582    male  54.0      0      0    28403      26.0000        S     311.0
# 254  female  41.0      0      2   370129      20.2125        S     375.5
# 480    male   9.0      5      2  CA 2144      46.9000        S     168.5
#
#      FamilySize  IsMinor
# 582           1    False
# 254           3    False
# 480           8     True

# %%
#  Map 'Sex' to numbers (male: 0, female: 1).

df['Sex']=df['Sex'].map({'male':0,'female':1})

df.sample(3)
# Out:
#      PassengerId  Survived  Pclass  \
# 388          389         0       3
# 683          684         0       3
# 591          592         1       1
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 388                             Sadlier, Mr. Matthew    0  28.0      0      0
# 683                      Goodwin, Mr. Charles Edward    0  14.0      5      2
# 591  Stephenson, Mrs. Walter Bertram (Martha Eustis)    1  52.0      1      0
#
#       Ticket  TicketPrice Embarked  FareRank  FamilySize  IsMinor
# 388   367655       7.7292        Q     793.0           1    False
# 683  CA 2144      46.9000        S     168.5           8     True
# 591    36947      78.2667        C      86.5           2    False

# %%
# Normalize the 'Fare' column.

df['FareNorm']=(df['TicketPrice']-df['TicketPrice'].min())/(df['TicketPrice'].max()-df['TicketPrice'].min())
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                            Name  Sex   Age  \
# 519          520         0       3             Pavlovic, Mr. Stefo    0  32.0
# 252          253         0       1       Stead, Mr. William Thomas    0  62.0
# 838          839         1       3                 Chip, Mr. Chang    0  32.0
# 27            28         0       1  Fortune, Mr. Charles Alexander    0  19.0
# 241          242         1       3  Murphy, Miss. Katherine "Kate"    1  28.0
#
#      SibSp  Parch  Ticket  TicketPrice Embarked  FareRank  FamilySize  \
# 519      0      0  349242       7.8958        S     687.5           1
# 252      0      0  113514      26.5500        S     277.0           1
# 838      0      0    1601      56.4958        S     133.0           1
# 27       3      2   19950     263.0000        S       5.5           6
# 241      1      0  367230      15.5000        Q     421.5           2
#
#      IsMinor  FareNorm
# 519    False  0.015412
# 252    False  0.051822
# ...

# %%
# Bin the 'Age' column into categories: Child, Teen, Adult, Senior.

df['Agegruop']=pd.cut(df['Age'],bins=[0,12,18,60,100],labels=['Child','Teen', 'Adult','Senior'])
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 206          207         0       3
# 307          308         1       1
# 523          524         1       1
# 325          326         1       1
# 65            66         1       3
# 394          395         1       3
# 302          303         0       3
# 499          500         0       3
# 890          891         0       3
# 581          582         1       1
#
#                                                   Name  Sex   Age  SibSp  \
# 206                         Backstrom, Mr. Karl Alfred    0  32.0      1
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...    1  17.0      1
# 523    Hippach, Mrs. Louis Albert (Ida Sophia Fischer)    1  44.0      0
# 325                           Young, Miss. Marie Grice    1  36.0      0
# 65                            Moubarek, Master. Gerios    0  28.0      1
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...    1  24.0      0
# ...

# %% [markdown]
# ### Boolean and Membership

# %%
# Find passengers with names containing 'Smith'.

df[df['Name'].str.contains('Smith',case=False,na=False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 165          166         1       3
# 174          175         0       1
# 260          261         0       3
# 284          285         0       1
# 328          329         1       3
# 346          347         1       2
# 548          549         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 165  Goldsmith, Master. Frank John William "Frankie"    0   9.0      0      2
# 174                          Smith, Mr. James Clinch    0  56.0      0      0
# 260                                Smith, Mr. Thomas    0  28.0      0      0
# 284                       Smith, Mr. Richard William    0  28.0      0      0
# 328   Goldsmith, Mrs. Frank John (Emily Alice Brown)    1  31.0      1      1
# 346                        Smith, Miss. Marion Elsie    1  40.0      0      0
# 548                        Goldsmith, Mr. Frank John    0  33.0      1      1
#
# ...

# %%
# Select rows where 'Ticket' starts with '3'.
df[df['Ticket'].str.startswith('3',na=False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 13            14         0       3
# ..           ...       ...     ...
# 877          878         0       3
# 878          879         0       3
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 4                             Allen, Mr. William Henry    0  35.0      0
# 5                                     Moran, Mr. James    0  28.0      0
# 7                       Palsson, Master. Gosta Leonard    0   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    1  27.0      0
# 13                         Andersson, Mr. Anders Johan    0  39.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
# Select passengers whose 'Age' is between 20 and 40.
# df[(df['Age']>=20) & (df['Age']<=40)]

df[df['Age'].between(20, 40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
# Select passengers who embarked from 'C' or 'Q'.

# df[(df['Embarked']=='C') | (df['Embarked']=='Q') ]

df[df['Embarked'].isin(['C', 'Q'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 5              6         0       3
# 9             10         1       2
# 16            17         0       3
# 19            20         1       3
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 885          886         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 5                                     Moran, Mr. James    0  28.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)    1  14.0      1
# 16                                Rice, Master. Eugene    0   2.0      4
# 19                             Masselmani, Mrs. Fatima    1  28.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
# Check if any passenger is older than 80.
# df[df['Age']>80]

(df['Age'] > 80).any()
# Out:
# False

# %% [markdown]
# ### Visualization

# %% [markdown]
# #### 1. Survival Count Plot (by Gender)

# %%
sns.countplot(data=df, x='Sex', hue='Survived')
plt.title('Survival Count by Gender')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.xlabel('Gender')
plt.ylabel('Passenger Count')
plt.show()

# %% [markdown]
# ##### Insight: Much higher survival rate among females compared to males

# %% [markdown]
# #### 2.Age Distribution

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Age'].dropna(),bins=30,kde=True)
plt.title("Age Distribution of Passangers")
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ##### Insight: Most passengers were between 20–40 years old.

# %% [markdown]
# ### 3.Survival by Passenger Class

# %%
sns.countplot(data=df,x='Pclass',hue='Survived')
plt.title("Survival Count by Pclass")
plt.xlabel("Pclass")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### Insight: 1st class passengers had a higher survival rate.

# %% [markdown]
# ### 4.Boxplot of Fare by Class

# %%
sns.boxplot(data=df, x='Pclass', y='TicketPrice')
plt.title('Fare Distribution by Class')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %% [markdown]
# ##### Insight:Higher classes paid significantly more on average.

# %% [markdown]
# ### 5.Embarked vs Survival Heatmap

# %%
Embarked_survival=pd.crosstab(df['Embarked'],df['Survived'])
sns.heatmap(Embarked_survival,annot=True,cmap='Blues')
plt.title("Survival by Embarked Port")
plt.xlabel('Survived')
plt.ylabel('Embarked Station')
# Out:
# Text(50.722222222222214, 0.5, 'Embarked Station')

# %% [markdown]
# ##### Insight: Passengers from 'C' had a higher proportion of survivors.

# %% [markdown]
# ### 6.Age vs Fare (with Survival Hue)

# %%
sns.scatterplot(data=df, x='Age', y='TicketPrice', hue='Survived')
plt.title('Age vs Fare by Survival')
plt.xlabel('Age')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %% [markdown]
# #### Insight: Some very young and elderly passengers paid high fares — mostly in 1st class.
